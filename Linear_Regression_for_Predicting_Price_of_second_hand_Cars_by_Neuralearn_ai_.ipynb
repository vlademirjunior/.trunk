# %% [markdown]
# <a href="https://colab.research.google.com/github/vlademirjunior/.trunk/blob/main/Linear_Regression_for_Predicting_Price_of_second_hand_Cars_by_Neuralearn_ai_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf### models
import pandas as pd ### reading and processing data
import seaborn as sns ### visualization
import numpy as np### math computations
import matplotlib.pyplot as plt### plotting bar chart
from tensorflow.keras.layers import Normalization, Dense, InputLayer
from tensorflow.keras.losses import MeanSquaredError, Huber, MeanAbsoluteError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Data Preparation**

# %%
# You can access train.csv at : https://drive.google.com/file/d/1QgFrgoqxqizKeuOmkBHccl_nNRV8xR89/view?usp=drive_link
data = pd.read_csv("/content/drive/MyDrive/neuralearn/course_data/train.csv", sep= ",")
data.head()
# Out:
#    v.id  on road old  on road now  years      km  rating  condition  economy  \
# 0     1       535651       798186      3   78945       1          2       14
# 1     2       591911       861056      6  117220       5          9        9
# 2     3       686990       770762      2  132538       2          8       15
# 3     4       573999       722381      4  101065       4          3       11
# 4     5       691388       811335      6   61559       3          9       12
#
#    top speed  hp  torque  current price
# 0        177  73     123       351318.0
# 1        148  74      95       285001.5
# 2        181  53      97       215386.0
# 3        197  54     116       244295.5
# 4        160  53     105       531114.5

# %%
data.shape
# Out:
# (1000, 12)

# %%
# data = pd.read_csv("train_semi.csv", ",")
# data.head()
# data.shape

# %%
sns.pairplot(data[['years', 'km', 'rating', 'condition', 'economy', 'top speed', 'hp', 'torque', 'current price']], diag_kind='kde')

# %%
tensor_data = tf.constant(data)
tensor_data = tf.cast(tensor_data, tf.float32)
print(tensor_data)
# Out:
# tf.Tensor(
# [[1.000000e+00 5.356510e+05 7.981860e+05 ... 7.300000e+01 1.230000e+02
#   3.513180e+05]
#  [2.000000e+00 5.919110e+05 8.610560e+05 ... 7.400000e+01 9.500000e+01
#   2.850015e+05]
#  [3.000000e+00 6.869900e+05 7.707620e+05 ... 5.300000e+01 9.700000e+01
#   2.153860e+05]
#  ...
#  [9.980000e+02 6.463440e+05 8.427330e+05 ... 1.130000e+02 8.900000e+01
#   4.058710e+05]
#  [9.990000e+02 5.355590e+05 7.324390e+05 ... 1.120000e+02 1.280000e+02
#   7.439800e+04]
#  [1.000000e+03 5.901050e+05 7.797430e+05 ... 9.900000e+01 9.600000e+01
#   4.149385e+05]], shape=(1000, 12), dtype=float32)

# %%
tensor_data = tf.random.shuffle(tensor_data)
print(tensor_data[:5])
# Out:
# tf.Tensor(
# [[9.460000e+02 5.084830e+05 7.886510e+05 3.000000e+00 1.016570e+05
#   3.000000e+00 4.000000e+00 1.200000e+01 1.780000e+02 7.100000e+01
#   1.240000e+02 2.427095e+05]
#  [2.070000e+02 5.754550e+05 8.067480e+05 6.000000e+00 1.365840e+05
#   1.000000e+00 8.000000e+00 1.100000e+01 1.820000e+02 1.080000e+02
#   7.900000e+01 1.575070e+05]
#  [8.600000e+02 5.897000e+05 7.546190e+05 2.000000e+00 7.303300e+04
#   4.000000e+00 3.000000e+00 1.500000e+01 1.430000e+02 8.900000e+01
#   1.100000e+02 3.809285e+05]
#  [8.250000e+02 5.128090e+05 8.616150e+05 3.000000e+00 8.842900e+04
#   5.000000e+00 7.000000e+00 1.400000e+01 1.740000e+02 5.400000e+01
#   8.500000e+01 3.435950e+05]
#  [4.140000e+02 5.067880e+05 8.554170e+05 2.000000e+00 1.233170e+05
#   2.000000e+00 2.000000e+00 1.300000e+01 1.800000e+02 8.800000e+01
#   1.250000e+02 1.881315e+05]], shape=(5, 12), dtype=float32)

# %%
X = tensor_data[:,3:-1]
print(X[:5])
# Out:
# tf.Tensor(
# [[3.00000e+00 1.01657e+05 3.00000e+00 4.00000e+00 1.20000e+01 1.78000e+02
#   7.10000e+01 1.24000e+02]
#  [6.00000e+00 1.36584e+05 1.00000e+00 8.00000e+00 1.10000e+01 1.82000e+02
#   1.08000e+02 7.90000e+01]
#  [2.00000e+00 7.30330e+04 4.00000e+00 3.00000e+00 1.50000e+01 1.43000e+02
#   8.90000e+01 1.10000e+02]
#  [3.00000e+00 8.84290e+04 5.00000e+00 7.00000e+00 1.40000e+01 1.74000e+02
#   5.40000e+01 8.50000e+01]
#  [2.00000e+00 1.23317e+05 2.00000e+00 2.00000e+00 1.30000e+01 1.80000e+02
#   8.80000e+01 1.25000e+02]], shape=(5, 8), dtype=float32)

# %%
y = tensor_data[:,-1]
print(y[:5].shape)
y = tf.expand_dims(y, axis = -1)
print(y[:5])
# Out:
# (5,)
# tf.Tensor(
# [[242709.5]
#  [157507. ]
#  [380928.5]
#  [343595. ]
#  [188131.5]], shape=(5, 1), dtype=float32)

# %%
normalizer = Normalization(axis = -1, mean = 5, variance = 4)
x_normalized = tf.constant([[3,4,5,6,7],
                            [4,5,6,7,8]])
normalizer(x_normalized)
# Out:
# <tf.Tensor: shape=(2, 5), dtype=float32, numpy=
# array([[-1. , -0.5,  0. ,  0.5,  1. ],
#        [-0.5,  0. ,  0.5,  1. ,  1.5]], dtype=float32)>

# %%
normalizer = Normalization()
x_normalized = tf.constant([[3,4,5,6,7],
                            [4,10,6,7,8],
                            [32,1,56,3,5]])
normalizer.adapt(x_normalized)
normalizer(x_normalized)
# Out:
# <tf.Tensor: shape=(3, 5), dtype=float32, numpy=
# array([[-0.7439795 , -0.26726124, -0.72800297,  0.3922322 ,  0.2672614 ],
#        [-0.6695816 ,  1.3363062 , -0.6860028 ,  0.9805806 ,  1.0690452 ],
#        [ 1.4135611 , -1.069045  ,  1.4140056 , -1.3728131 , -1.3363061 ]],
#       dtype=float32)>

# %%
print(X.shape, y.shape)
# Out:
# (1000, 8) (1000, 1)

# %%
TRAIN_RATIO = 0.8
VAL_RATIO = 0.1
TEST_RATIO = 0.1
DATASET_SIZE = len(X)

# %%
X_train = X[:int(DATASET_SIZE*TRAIN_RATIO)]
y_train = y[:int(DATASET_SIZE*TRAIN_RATIO)]
print(X_train.shape)
print(y_train.shape)
# Out:
# (800, 8)
# (800, 1)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train_dataset = train_dataset.shuffle(buffer_size = 8, reshuffle_each_iteration = True).prefetch(tf.data.AUTOTUNE)

# %%
print(X.shape)
print(y.shape)
# Out:
# (1000, 8)
# (1000, 1)

# %%
X_val = X[int(DATASET_SIZE*TRAIN_RATIO):int(DATASET_SIZE*(TRAIN_RATIO+VAL_RATIO))]
y_val = y[int(DATASET_SIZE*TRAIN_RATIO):int(DATASET_SIZE*(TRAIN_RATIO+VAL_RATIO))]
print(X_val.shape)
print(y_val.shape)
# Out:
# (100, 8)
# (100, 1)

# %%
val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val))
val_dataset = train_dataset.shuffle(buffer_size = 8, reshuffle_each_iteration = True).prefetch(tf.data.AUTOTUNE)

# %%
X_test = X[int(DATASET_SIZE*(TRAIN_RATIO+VAL_RATIO)):]
y_test = y[int(DATASET_SIZE*(TRAIN_RATIO+VAL_RATIO)):]
print(X_test.shape)
print(y_test.shape)
# Out:
# (100, 8)
# (100, 1)

# %%
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test))
test_dataset = train_dataset.shuffle(buffer_size = 8, reshuffle_each_iteration = True).prefetch(tf.data.AUTOTUNE)

# %%
normalizer = Normalization()
normalizer.adapt(X_train)
normalizer(X)[:5]
# Out:
# <tf.Tensor: shape=(5, 8), dtype=float32, numpy=
# array([[-0.8849987 ,  0.03477528, -0.0035761 , -0.53458196,  0.15091792,
#          0.58814085, -0.66344535,  0.9714487 ],
#        [ 0.8574107 ,  1.2221818 , -1.4339824 ,  0.87221265, -0.2962468 ,
#          0.7961022 ,  1.1385354 , -1.1642553 ],
#        [-1.4658017 , -0.9383493 ,  0.711627  , -0.8862806 ,  1.4924121 ,
#         -1.2315214 ,  0.21319392,  0.30700746],
#        [-0.8849987 , -0.4149345 ,  1.4268302 ,  0.520514  ,  1.0452473 ,
#          0.38017944, -1.4913825 , -0.8794948 ],
#        [-1.4658017 ,  0.7711461 , -0.7187792 , -1.2379793 ,  0.59808266,
#          0.6921215 ,  0.16449174,  1.0189087 ]], dtype=float32)>

# %%
print(X[:5])
# Out:
# tf.Tensor(
# [[3.00000e+00 1.01657e+05 3.00000e+00 4.00000e+00 1.20000e+01 1.78000e+02
#   7.10000e+01 1.24000e+02]
#  [6.00000e+00 1.36584e+05 1.00000e+00 8.00000e+00 1.10000e+01 1.82000e+02
#   1.08000e+02 7.90000e+01]
#  [2.00000e+00 7.30330e+04 4.00000e+00 3.00000e+00 1.50000e+01 1.43000e+02
#   8.90000e+01 1.10000e+02]
#  [3.00000e+00 8.84290e+04 5.00000e+00 7.00000e+00 1.40000e+01 1.74000e+02
#   5.40000e+01 8.50000e+01]
#  [2.00000e+00 1.23317e+05 2.00000e+00 2.00000e+00 1.30000e+01 1.80000e+02
#   8.80000e+01 1.25000e+02]], shape=(5, 8), dtype=float32)

# %%
train_dataset = train_dataset.batch(8)
val_dataset = val_dataset.batch(8)

# %% [markdown]
# ## **Model Creation and Training**

# %%
model = tf.keras.Sequential([
                             InputLayer(input_shape = (8,)),
                             normalizer,
                             Dense(128, activation = "relu"),
                             Dense(128, activation = "relu"),
                             Dense(128, activation = "relu"),
                             Dense(1),
])
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization_13                │ (None, 8)              │            17 │
# │ (Normalization)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 128)            │         1,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,322 (134.07 KB)
#  Trainable params: 34,305 (134.00 KB)
#  Non-trainable params: 17 (72.00 B)

# %%
tf.keras.utils.plot_model(model, to_file = "model.png", show_shapes=True)

# %%
model.compile(optimizer = Adam(learning_rate = 0.1),
              loss = MeanAbsoluteError(),
              metrics = [RootMeanSquaredError()])

# %%
history = model.fit(train_dataset, validation_data=val_dataset, epochs = 100, verbose = 1)
# Out:
# Epoch 1/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 146098.8281 - root_mean_squared_error: 184255.9062 - val_loss: 62792.2695 - val_root_mean_squared_error: 75636.1250
# Epoch 2/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 54399.7070 - root_mean_squared_error: 68208.6641 - val_loss: 41495.9219 - val_root_mean_squared_error: 51507.1289
# Epoch 3/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 48955.2188 - root_mean_squared_error: 62887.0547 - val_loss: 60121.8984 - val_root_mean_squared_error: 71817.4219
# Epoch 4/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 48204.0195 - root_mean_squared_error: 61708.0391 - val_loss: 71016.7500 - val_root_mean_squared_error: 84027.8672
# Epoch 5/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 52372.2617 - root_mean_squared_error: 66053.9141 - val_loss: 36483.1836 - val_root_mean_squared_error: 44841.8477
# Epoch 6/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 42780.8945 - root_mean_squared_error: 53100.9453 - val_loss: 48888.4297 - val_root_mean_squared_error: 59579.7031
# Epoch 7/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 41886.0156 - root_mean_squared_error: 53320.6914 - val_loss: 46684.0586 - val_root_mean_squared_error: 56871.1211
# Epoch 8/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 43582.3359 - root_mean_squared_error: 53606.9258 - val_loss: 49676.2305 - val_root_mean_squared_error: 62663.1211
# Epoch 9/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 48340.4141 - root_mean_squared_error: 61229.6797 - val_loss: 40533.3828 - val_root_mean_squared_error: 49949.6914
# Epoch 10/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 40804.4180 - root_mean_squared_error: 51172.3281 - val_loss: 41893.8398 - val_root_mean_squared_error: 51615.2344
# Epoch 11/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 42524.4805 - root_mean_squared_error: 52264.6250 - val_loss: 40863.2109 - val_root_mean_squared_error: 50390.6406
# Epoch 12/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 41493.5430 - root_mean_squared_error: 52275.9570 - val_loss: 43410.3281 - val_root_mean_squared_error: 54195.8516
# Epoch 13/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 42814.7305 - root_mean_squared_error: 53769.2500 - val_loss: 39253.2539 - val_root_mean_squared_error: 48482.1445
# Epoch 14/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 40401.4023 - root_mean_squared_error: 50991.4023 - val_loss: 39970.0078 - val_root_mean_squared_error: 49500.1562
# Epoch 15/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 38536.2812 - root_mean_squared_error: 48366.1836 - val_loss: 41852.0703 - val_root_mean_squared_error: 51802.3828
# Epoch 16/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 36573.1875 - root_mean_squared_error: 46092.0039 - val_loss: 46392.3789 - val_root_mean_squared_error: 56619.0977
# Epoch 17/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 37233.8164 - root_mean_squared_error: 46421.8867 - val_loss: 38091.1367 - val_root_mean_squared_error: 47245.1562
# Epoch 18/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 38183.7891 - root_mean_squared_error: 47276.0508 - val_loss: 44630.3516 - val_root_mean_squared_error: 54757.1758
# Epoch 19/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 36457.3906 - root_mean_squared_error: 45313.5547 - val_loss: 36180.5234 - val_root_mean_squared_error: 44456.4531
# Epoch 20/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 35733.1641 - root_mean_squared_error: 45344.2344 - val_loss: 45269.5898 - val_root_mean_squared_error: 55297.4258
# Epoch 21/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 36107.5938 - root_mean_squared_error: 44876.2695 - val_loss: 37396.5781 - val_root_mean_squared_error: 46080.9453
# Epoch 22/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 37535.1523 - root_mean_squared_error: 47156.4648 - val_loss: 37280.0938 - val_root_mean_squared_error: 45938.4453
# Epoch 23/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 37213.1836 - root_mean_squared_error: 47053.2148 - val_loss: 40384.9961 - val_root_mean_squared_error: 49847.5469
# Epoch 24/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 33852.8789 - root_mean_squared_error: 42180.4961 - val_loss: 37059.6641 - val_root_mean_squared_error: 45566.3750
# Epoch 25/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 33474.3594 - root_mean_squared_error: 41437.3086 - val_loss: 40017.1211 - val_root_mean_squared_error: 49554.7227
# Epoch 26/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34145.7188 - root_mean_squared_error: 42936.4453 - val_loss: 38158.0039 - val_root_mean_squared_error: 47090.1562
# Epoch 27/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 42238.0117 - root_mean_squared_error: 52824.0078 - val_loss: 47128.1055 - val_root_mean_squared_error: 58277.7617
# Epoch 28/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 36048.7656 - root_mean_squared_error: 44679.5391 - val_loss: 49085.1914 - val_root_mean_squared_error: 59741.1406
# Epoch 29/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 36547.0117 - root_mean_squared_error: 46025.3750 - val_loss: 52758.0547 - val_root_mean_squared_error: 64238.8945
# Epoch 30/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 38428.7383 - root_mean_squared_error: 48075.0469 - val_loss: 59601.5156 - val_root_mean_squared_error: 71425.7188
# Epoch 31/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 36489.7930 - root_mean_squared_error: 45886.4844 - val_loss: 46211.7734 - val_root_mean_squared_error: 56698.8828
# Epoch 32/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 36642.3086 - root_mean_squared_error: 45235.6055 - val_loss: 45529.2344 - val_root_mean_squared_error: 56509.3594
# Epoch 33/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34366.8438 - root_mean_squared_error: 42491.5469 - val_loss: 46933.5000 - val_root_mean_squared_error: 57434.8125
# Epoch 34/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 33840.6562 - root_mean_squared_error: 42404.3945 - val_loss: 61620.4258 - val_root_mean_squared_error: 73258.4141
# Epoch 35/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 35418.1016 - root_mean_squared_error: 44267.4727 - val_loss: 48990.0508 - val_root_mean_squared_error: 60172.2969
# Epoch 36/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34986.8398 - root_mean_squared_error: 43803.2695 - val_loss: 50210.4453 - val_root_mean_squared_error: 61129.1875
# Epoch 37/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 35764.8672 - root_mean_squared_error: 44897.5195 - val_loss: 41775.1992 - val_root_mean_squared_error: 51986.6055
# Epoch 38/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 32554.5820 - root_mean_squared_error: 40848.2969 - val_loss: 50466.7891 - val_root_mean_squared_error: 61771.9219
# Epoch 39/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 35119.7070 - root_mean_squared_error: 43999.7461 - val_loss: 45713.2383 - val_root_mean_squared_error: 56180.1758
# Epoch 40/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 33184.2500 - root_mean_squared_error: 41458.9609 - val_loss: 49761.8047 - val_root_mean_squared_error: 60456.8398
# Epoch 41/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 34083.9414 - root_mean_squared_error: 42350.8281 - val_loss: 53586.9805 - val_root_mean_squared_error: 65116.0781
# Epoch 42/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 33364.1055 - root_mean_squared_error: 41766.9336 - val_loss: 54332.9258 - val_root_mean_squared_error: 65895.1406
# Epoch 43/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 35469.0703 - root_mean_squared_error: 44237.5938 - val_loss: 45299.9102 - val_root_mean_squared_error: 55905.3164
# Epoch 44/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 35348.2422 - root_mean_squared_error: 44434.6016 - val_loss: 38835.1875 - val_root_mean_squared_error: 48430.5547
# Epoch 45/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 33142.7305 - root_mean_squared_error: 41410.0508 - val_loss: 45413.1953 - val_root_mean_squared_error: 56302.3555
# Epoch 46/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 35546.6797 - root_mean_squared_error: 44333.9492 - val_loss: 35844.8750 - val_root_mean_squared_error: 44691.5195
# Epoch 47/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 33432.6914 - root_mean_squared_error: 42145.3242 - val_loss: 45655.0000 - val_root_mean_squared_error: 56083.2031
# Epoch 48/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 31984.2188 - root_mean_squared_error: 40073.0234 - val_loss: 43183.8242 - val_root_mean_squared_error: 53318.8125
# Epoch 49/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 33804.0352 - root_mean_squared_error: 42810.2422 - val_loss: 47063.4961 - val_root_mean_squared_error: 58504.0820
# Epoch 50/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 33779.6680 - root_mean_squared_error: 42925.2422 - val_loss: 55581.8906 - val_root_mean_squared_error: 67517.9844
# Epoch 51/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 36421.8984 - root_mean_squared_error: 45033.3398 - val_loss: 43687.6367 - val_root_mean_squared_error: 54042.1602
# Epoch 52/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 37061.1406 - root_mean_squared_error: 46703.1133 - val_loss: 40673.3242 - val_root_mean_squared_error: 50599.6836
# Epoch 53/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34205.7383 - root_mean_squared_error: 42653.5039 - val_loss: 42869.5469 - val_root_mean_squared_error: 53342.8516
# Epoch 54/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 34528.8008 - root_mean_squared_error: 43365.1445 - val_loss: 41896.4453 - val_root_mean_squared_error: 52261.6875
# Epoch 55/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 35173.6445 - root_mean_squared_error: 44817.6523 - val_loss: 44466.8281 - val_root_mean_squared_error: 54725.0078
# Epoch 56/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34864.8359 - root_mean_squared_error: 43814.1797 - val_loss: 39381.9141 - val_root_mean_squared_error: 48831.2031
# Epoch 57/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 34571.9570 - root_mean_squared_error: 44231.9570 - val_loss: 39665.6367 - val_root_mean_squared_error: 49471.6758
# Epoch 58/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 33996.8086 - root_mean_squared_error: 42733.2422 - val_loss: 34453.5000 - val_root_mean_squared_error: 42919.1836
# Epoch 59/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 33185.9336 - root_mean_squared_error: 42645.0859 - val_loss: 37102.5664 - val_root_mean_squared_error: 46093.8945
# Epoch 60/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 34452.4531 - root_mean_squared_error: 44184.5664 - val_loss: 32020.0293 - val_root_mean_squared_error: 39339.6055
# Epoch 61/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 34021.7734 - root_mean_squared_error: 42241.7578 - val_loss: 31466.0977 - val_root_mean_squared_error: 38974.0156
# Epoch 62/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 31712.1914 - root_mean_squared_error: 40483.9375 - val_loss: 33189.5156 - val_root_mean_squared_error: 41516.5625
# Epoch 63/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 33385.8477 - root_mean_squared_error: 42260.7148 - val_loss: 38155.9844 - val_root_mean_squared_error: 47539.7734
# Epoch 64/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 32802.5664 - root_mean_squared_error: 41404.5273 - val_loss: 32718.6855 - val_root_mean_squared_error: 40726.8359
# Epoch 65/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 32243.8984 - root_mean_squared_error: 40469.1133 - val_loss: 35116.5352 - val_root_mean_squared_error: 43500.2695
# Epoch 66/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 36453.5000 - root_mean_squared_error: 45651.8008 - val_loss: 30335.2266 - val_root_mean_squared_error: 38170.1016
# Epoch 67/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 30652.6562 - root_mean_squared_error: 38548.7500 - val_loss: 32044.3223 - val_root_mean_squared_error: 40020.9141
# Epoch 68/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 31198.6797 - root_mean_squared_error: 39821.7227 - val_loss: 34506.9688 - val_root_mean_squared_error: 43354.1289
# Epoch 69/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31914.1934 - root_mean_squared_error: 40387.2734 - val_loss: 33309.6094 - val_root_mean_squared_error: 41600.2812
# Epoch 70/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 31050.7246 - root_mean_squared_error: 39092.5938 - val_loss: 33123.5117 - val_root_mean_squared_error: 41503.3398
# Epoch 71/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 31122.1094 - root_mean_squared_error: 39809.2070 - val_loss: 31703.1953 - val_root_mean_squared_error: 39951.4375
# Epoch 72/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31778.1211 - root_mean_squared_error: 40393.7812 - val_loss: 32315.9570 - val_root_mean_squared_error: 40244.2539
# Epoch 73/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30075.6152 - root_mean_squared_error: 38264.9414 - val_loss: 37544.9531 - val_root_mean_squared_error: 46983.7695
# Epoch 74/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 32177.4434 - root_mean_squared_error: 40968.5586 - val_loss: 33138.0234 - val_root_mean_squared_error: 41531.5820
# Epoch 75/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31843.4707 - root_mean_squared_error: 40527.5820 - val_loss: 30955.0000 - val_root_mean_squared_error: 38766.3789
# Epoch 76/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 31283.0176 - root_mean_squared_error: 39465.4102 - val_loss: 31159.5234 - val_root_mean_squared_error: 38776.3047
# Epoch 77/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 31646.7207 - root_mean_squared_error: 40113.3008 - val_loss: 32389.7617 - val_root_mean_squared_error: 40336.7344
# Epoch 78/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 31237.1289 - root_mean_squared_error: 39863.6367 - val_loss: 30672.7031 - val_root_mean_squared_error: 38505.8203
# Epoch 79/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 30451.5879 - root_mean_squared_error: 38886.1016 - val_loss: 31897.4023 - val_root_mean_squared_error: 39925.5625
# Epoch 80/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 30879.5566 - root_mean_squared_error: 39678.8320 - val_loss: 32115.7246 - val_root_mean_squared_error: 40563.5352
# Epoch 81/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29932.2461 - root_mean_squared_error: 38392.5586 - val_loss: 32389.9668 - val_root_mean_squared_error: 39992.9531
# Epoch 82/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 30662.3574 - root_mean_squared_error: 38989.2148 - val_loss: 29767.3594 - val_root_mean_squared_error: 37624.1953
# Epoch 83/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 30320.0625 - root_mean_squared_error: 38909.5234 - val_loss: 33235.4688 - val_root_mean_squared_error: 41709.6445
# Epoch 84/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 30296.4570 - root_mean_squared_error: 38836.3750 - val_loss: 30901.2520 - val_root_mean_squared_error: 38997.3594
# Epoch 85/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 31198.7031 - root_mean_squared_error: 40436.3398 - val_loss: 30345.0781 - val_root_mean_squared_error: 37786.0234
# Epoch 86/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31837.2617 - root_mean_squared_error: 40988.6562 - val_loss: 30118.4199 - val_root_mean_squared_error: 38156.0977
# Epoch 87/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 31343.9805 - root_mean_squared_error: 40046.7539 - val_loss: 32538.6426 - val_root_mean_squared_error: 41242.2500
# Epoch 88/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30723.0059 - root_mean_squared_error: 39130.2578 - val_loss: 30846.3301 - val_root_mean_squared_error: 38961.9102
# Epoch 89/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31338.4453 - root_mean_squared_error: 39921.1289 - val_loss: 30269.3418 - val_root_mean_squared_error: 38380.8555
# Epoch 90/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 30942.1113 - root_mean_squared_error: 39350.0586 - val_loss: 29478.9082 - val_root_mean_squared_error: 37218.9609
# Epoch 91/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 31622.1113 - root_mean_squared_error: 40078.4414 - val_loss: 30702.2402 - val_root_mean_squared_error: 38639.4492
# Epoch 92/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29820.5137 - root_mean_squared_error: 38300.0977 - val_loss: 36231.4531 - val_root_mean_squared_error: 45306.3594
# Epoch 93/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31495.5859 - root_mean_squared_error: 40567.9023 - val_loss: 30194.6855 - val_root_mean_squared_error: 38221.1758
# Epoch 94/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29717.0156 - root_mean_squared_error: 38305.7148 - val_loss: 29420.0957 - val_root_mean_squared_error: 38094.2734
# Epoch 95/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29367.6445 - root_mean_squared_error: 37375.6250 - val_loss: 34350.0234 - val_root_mean_squared_error: 43295.5742
# Epoch 96/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 33092.3320 - root_mean_squared_error: 41994.4883 - val_loss: 30544.1523 - val_root_mean_squared_error: 38440.6953
# Epoch 97/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29365.5371 - root_mean_squared_error: 38064.7109 - val_loss: 28805.4082 - val_root_mean_squared_error: 37006.5039
# Epoch 98/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 28370.8164 - root_mean_squared_error: 36992.8984 - val_loss: 28333.5273 - val_root_mean_squared_error: 36405.7031
# Epoch 99/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 28635.4316 - root_mean_squared_error: 37038.4258 - val_loss: 28809.3848 - val_root_mean_squared_error: 37287.1680
# Epoch 100/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 27921.8262 - root_mean_squared_error: 36619.1836 - val_loss: 29337.9180 - val_root_mean_squared_error: 37522.2305

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val_loss'])
plt.show()

# %%
plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('model performance')
plt.ylabel('rmse')
plt.xlabel('epoch')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# ## **Model Evaluation and Testing**

# %%
model.evaluate(X_test,y_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - loss: 37720.3125 - root_mean_squared_error: 47049.5352
# [36453.80078125, 46125.0]

# %%
X_test.shape
# Out:
# TensorShape([100, 8])

# %%
model.predict(tf.expand_dims(X_test[0], axis = 0 ))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# array([[178490.44]], dtype=float32)

# %%
y_test[0]
# Out:
# <tf.Tensor: shape=(1,), dtype=float32, numpy=array([97526.], dtype=float32)>

# %%
y_true = list(y_test[:,0].numpy())

# %%
y_pred = list(model.predict(X_test)[:,0])
print(y_pred)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# [np.float32(178490.44), np.float32(153073.25), np.float32(278322.6), np.float32(373573.47), np.float32(378594.2), np.float32(473903.0), np.float32(410310.3), np.float32(330464.6), np.float32(334918.8), np.float32(266835.9), np.float32(312188.03), np.float32(309114.34), np.float32(487882.56), np.float32(451973.66), np.float32(126698.52), np.float32(338690.28), np.float32(433933.8), np.float32(120077.336), np.float32(246229.9), np.float32(397113.44), np.float32(371242.4), np.float32(204909.81), np.float32(245494.83), np.float32(143502.39), np.float32(157911.64), np.float32(347690.06), np.float32(70472.62), np.float32(511669.3), np.float32(454234.06), np.float32(304321.0), np.float32(233598.6), np.float32(156791.4), np.float32(516848.7), np.float32(152640.34), np.float32(420990.7), np.float32(354390.22), np.float32(350823.53), np.float32(313452.75), np.float32(478940.44), np.float32(546805.44), np.float32(507980.94), np.float32(399416.75), np.float32(438150.75), np.float32(299040.56), np.float32(155659.11), np.float32(262779.03), np.float32(378906.56), np.float32(311248.38), np.float32(398231.7), np.float32(197391.31), np.float32(191503.67), np.float32(259323.7), np.float32(317220.72), np.float32(338451.47), np.float32(416418.8), np.float32(299746.12), np.float32(167996.97), np.float32(532657.4), np.float32(163267.84), np.float32(532647.44), np.float32(390937.1), np.float32(467124.72), np.float32(307213.66), np.float32(398492.1), np.float32(316668.56), np.float32(370028.38), np.float32(237988.75), np.float32(387641.97), np.float32(481482.28), np.float32(307117.2), np.float32(261470.42), np.float32(359565.9), np.float32(116869.195), np.float32(197800.02), np.float32(217479.77), np.float32(337638.88), np.float32(84343.2), np.float32(198074.22), np.float32(319774.44), np.float32(166689.77), np.float32(433054.88), np.float32(462433.88), np.float32(388702.88), np.float32(160750.03), np.float32(529734.3), np.float32(331166.2), np.float32(393668.12), np.float32(122150.016), np.float32(166749.45), np.float32(409109.12), np.float32(553720.8), np.float32(388183.56), np.float32(205972.55), np.float32(351911.1), np.float32(172087.75), np.float32(377896.8), np.float32(176494.1), np.float32(308280.2), np.float32(457504.44), np.float32(225287.64)]

# %%
ind = np.arange(100)
plt.figure(figsize=(40,20))

width = 0.1

plt.bar(ind, y_pred, width, label='Predicted Car Price')
plt.bar(ind + width, y_true, width, label='Actual Car Price')

plt.xlabel('Actual vs Predicted Prices')
plt.ylabel('Car Price Prices')

plt.show()
